# %%
import pandas as pd 
import numpy as np

# %%
il_ilce=pd.read_csv("data/il_ilce.csv")
il_ilce.il=il_ilce.il.str.lower()
il_ilce.ilce=il_ilce.ilce.str.lower()
il_ilce.head()
# Out:
#       il       ilce
# 0  adana     aladağ
# 1  adana     ceyhan
# 2  adana       feke
# 3  adana  karaisalı
# 4  adana    karataş

# %%
train=pd.read_csv("data/train.csv",low_memory=False)

# %%
train["Dogum Yeri"]=train["Dogum Yeri"].fillna("Diger")

# %%
dogum_y=train["Dogum Yeri"]

# %%
dogum_y=dogum_y.str.lower()

# %%
dogum_y
# Out:
# 0        altindag, ankara
# 1                 üsküdar
# 2                  samsun
# 3              diyarbakır
# 4         ankara/altındağ
#                ...
# 65120           i̇stanbul
# 65121               hatay
# 65122              mersin
# 65123              samsun
# 65124               hatay
# Name: Dogum Yeri, Length: 65125, dtype: object

# %%
import re

# %%
a="altindag/ankara sakarya"
result = re.split(r'[ ,/-]', a)

# %%
result
# Out:
# ['altindag', 'ankara', 'sakarya']

# %%
for i in result: 
    if "Adana" in il_ilce.il.unique():
        print("a")

# %%
il_ilce.il.unique()
# Out:
# array(['adana', 'adıyaman', 'afyonkarahisar', 'aksaray', 'amasya',
#        'ankara', 'antalya', 'ardahan', 'artvin', 'aydın', 'ağrı',
#        'balıkesir', 'bartın', 'batman', 'bayburt', 'bilecik', 'bingöl',
#        'bitlis', 'bolu', 'burdur', 'bursa', 'denizli', 'diyarbakır',
#        'düzce', 'edirne', 'elazığ', 'erzincan', 'erzurum', 'eskişehir',
#        'gaziantep', 'giresun', 'gümüşhane', 'hakkâri', 'hatay', 'isparta',
#        'iğdır', 'kahramanmaraş', 'karabük', 'karaman', 'kars',
#        'kastamonu', 'kayseri', 'kilis', 'kocaeli', 'konya', 'kütahya',
#        'kırklareli', 'kırıkkale', 'kırşehir', 'malatya', 'manisa',
#        'mardin', 'mersin', 'muğla', 'muş', 'nevşehir', 'niğde', 'ordu',
#        'osmaniye', 'rize', 'sakarya', 'samsun', 'siirt', 'sinop', 'sivas',
#        'tekirdağ', 'tokat', 'trabzon', 'tunceli', 'uşak', 'van', 'yalova',
#        'yozgat', 'zonguldak', 'çanakkale', 'çankırı', 'çorum',
#        'i̇stanbul', 'i̇zmir', 'şanlıurfa', 'şırnak'], dtype=object)

# %%
city_district_dict = il_ilce.groupby('il')['ilce'].apply(list).to_dict()

# Sonuç
# Out:
# {'adana': ['aladağ', 'ceyhan', 'feke', 'karaisalı', 'karataş', 'kozan', 'pozantı', 'saimbeyli', 'sarıçam', 'seyhan', 'tufanbeyli', 'yumurtalık', 'yüreğir', 'çukurova', 'i̇mamoğlu'], 'adıyaman': ['adıyaman merkez', 'besni', 'gerger', 'gölbaşı', 'kahta', 'samsat', 'sincik', 'tut', 'çelikhan'], 'afyonkarahisar': ['afyonkarahisar merkez', 'bayat', 'başmakçı', 'bolvadin', 'dazkırı', 'dinar', 'emirdağ', 'evciler', 'hocalar', 'kızılören', 'sandıklı', 'sinanpaşa', 'sultandağı', 'çay', 'çobanlar', 'i̇hsaniye', 'i̇scehisar', 'şuhut'], 'aksaray': ['aksaray merkez', 'ağaçören', 'eskil', 'gülağaç', 'güzelyurt', 'ortaköy', 'sarıyahşi', 'sultanhanı'], 'amasya': ['amasya merkez', 'göynücek', 'gümüşhacıköy', 'hamamözü', 'merzifon', 'suluova', 'taşova'], 'ankara': ['akyurt', 'altındağ', 'ayaş', 'bala', 'beypazarı', 'elmadağ', 'etimesgut', 'evren', 'gölbaşı', 'güdül', 'haymana', 'kahramankazan', 'kalecik', 'keçiören', 'kızılcahamam', 'mamak', 'nallıhan', 'polatlı', 'pursaklar', 'sincan', 'yenimahalle', 'çamlıdere', 'çankaya', 'çubuk', 'şereflikoçhisar'], 'antalya': ['akseki', 'aksu', 'alanya', 'demre', 'döşemealtı', 'elmalı', 'finike', 'gazipaşa', 'gündoğmuş', 'kaş', 'kemer', 'kepez', 'konyaaltı', 'korkuteli', 'kumluca', 'manavgat', 'muratpaşa', 'serik', 'i̇bradı'], 'ardahan': ['ardahan merkez', 'damal', 'göle', 'hanak', 'posof', 'çıldır'], 'artvin': ['ardanuç', 'arhavi', 'artvin merkez', 'borçka', 'hopa', 'kemalpaşa', 'murgul', 'yusufeli', 'şavşat'], 'aydın': ['bozdoğan', 'buharkent', 'didim', 'efeler', 'germencik', 'karacasu', 'karpuzlu', 'koçarlı', 'kuyucak', 'kuşadası', 'köşk', 'nazilli', 'sultanhisar', 'söke', 'yenipazar', 'çine', 'i̇ncirliova'], 'ağrı': ['ağrı merkez', 'diyadin', 'doğubayazıt', 'eleşkirt', 'hamur', 'patnos', 'taşlıçay', 'tutak'], 'balıkesir': ['altıeylül', 'ayvalık', 'balya', 'bandırma', 'bigadiç', 'burhaniye', 'dursunbey', 'edremit', 'erdek', 'gömeç', 'gönen', 'havran', 'karesi', 'kepsut', 'manyas', 'marmara', 'savaştepe', 'susurluk', 'sındırgı', 'i̇vrindi'], 'bartın': ['amasra', 'bartın merkez', 'kurucaşile', 'ulus'], 'batman': ['batman merkez', 'beşiri', 'gercüş', 'hasankeyf', 'kozluk', 'sason'], 'bayburt': ['aydıntepe', 'bayburt merkez', 'demirözü'], 'bilecik': ['bilecik merkez', 'bozüyük', 'gölpazarı', 'osmaneli', 'pazaryeri', 'söğüt', 'yenipazar', 'i̇nhisar'], 'bingöl': ['adaklı', 'bingöl merkez', 'genç', 'karlıova', 'kiğı', 'solhan', 'yayladere', 'yedisu'], 'bitlis': ['adilcevaz', 'ahlat', 'bitlis merkez', 'güroymak', 'hizan', 'mutki', 'tatvan'], 'bolu': ['bolu merkez', 'dörtdivan', 'gerede', 'göynük', 'kıbrıscık', 'mengen', 'mudurnu', 'seben', 'yeniçağa'], 'burdur': ['altınyayla', 'ağlasun', 'bucak', 'burdur merkez', 'gölhisar', 'karamanlı', 'kemer', 'tefenni', 'yeşilova', 'çavdır', 'çeltikçi'], 'bursa': ['büyükorhan', 'gemlik', 'gürsu', 'harmancık', 'karacabey', 'keles', 'kestel', 'mudanya', 'mustafakemalpaşa', 'nilüfer', 'orhaneli', 'orhangazi', 'osmangazi', 'yenişehir', 'yıldırım', 'i̇negöl', 'i̇znik'], 'denizli': ['acıpayam', 'babadağ', 'baklan', 'bekilli', 'beyağaç', 'bozkurt', 'buldan', 'güney', 'honaz', 'kale', 'merkezefendi', 'pamukkale', 'sarayköy', 'serinhisar', 'tavas', 'çal', 'çameli', 'çardak', 'çivril'], 'diyarbakır': ['bağlar', 'bismil', 'dicle', 'ergani', 'eğil', 'hani', 'hazro', 'kayapınar', 'kocaköy', 'kulp', 'lice', 'silvan', 'sur', 'yenişehir', 'çermik', 'çüngüş', 'çınar'], 'düzce': ['akçakoca', 'cumayeri', 'düzce merkez', 'gölyaka', 'gümüşova', 'kaynaşlı', 'yığılca', 'çilimli'], 'edirne': ['edirne merkez', 'enez', 'havsa', 'keşan', 'lalapaşa', 'meriç', 'süloğlu', 'uzunköprü', 'i̇psala'], 'elazığ': ['alacakaya', 'arıcak', 'ağın', 'baskil', 'elazığ merkez', 'karakoçan', 'keban', 'kovancılar', 'maden', 'palu', 'sivrice'], 'erzincan': ['erzincan merkez', 'kemah', 'kemaliye', 'otlukbeli', 'refahiye', 'tercan', 'çayırlı', 'üzümlü', 'i̇liç'], 'erzurum': ['aziziye', 'aşkale', 'horasan', 'hınıs', 'karayazı', 'karaçoban', 'köprüköy', 'narman', 'oltu', 'olur', 'palandöken', 'pasinler', 'pazaryolu', 'tekma ...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[26], line 4
#       1 city_district_dict = il_ilce.groupby('il')['ilce'].apply(list).to_dict()
#       3 # Sonuç
# ----> 4 print(city_district_dict).items()
#
# AttributeError: 'NoneType' object has no attribute 'items'

# %%
for il,ilce in city_district_dict.items():
    print(il)
    print(ilce)

# %%
dogum_yeri=[]
for k in dogum_y:
    appended=False
    result = re.split(r'[ ,/-]', k)
    for i in result:
        if appended==True:
            break
        for il,ilce in city_district_dict.items():
            if i == il:
                dogum_yeri.append(il)
                appended=True
                break
            elif i in ilce:
                dogum_yeri.append(il)
                appended=True
                break
    if appended==False:
        dogum_yeri.append("Diger")
        append=True

# %%
len(dogum_yeri),dogum_yeri
# Out:
# (65125,
#  ['ankara',
#   'i̇stanbul',
#   'samsun',
#   'diyarbakır',
#   'ankara',
#   'i̇stanbul',
#   'i̇stanbul',
#   'i̇stanbul',
#   'erzincan',
#   'sivas',
#   'kayseri',
#   'uşak',
#   'rize',
#   'ankara',
#   'adıyaman',
#   'erzurum',
#   'Diger',
#   'konya',
#   'i̇zmir',
#   'trabzon',
#   'kars',
#   'kırşehir',
#   'Diger',
#   'adana',
#   'Diger',
#   'i̇stanbul',
#   'ankara',
#   'adana',
#   'adana',
#   'Diger',
#   'sakarya',
#   'i̇stanbul',
#   'adana',
#   'ankara',
#   'ankara',
#   'muğla',
#   'kars',
#   'hatay',
#   'Diger',
#   'i̇zmir',
#   'i̇stanbul',
#   'ankara',
#   'mersin',
#   'i̇zmir',
#   'erzurum',
#   'malatya',
#   'i̇stanbul',
#   'manisa',
#   'i̇stanbul',
#   'kayseri',
#   'Diger',
#   'çorum',
#   'Diger',
#   'çanakkale',
#   'Diger',
#   'ankara',
#   'Diger',
#   'antalya',
#   'bursa',
#   'ankara',
#   'ordu',
#   'antalya',
#   'konya',
#   'çankırı',
#   'i̇stanbul',
#   'malatya',
#   'ankara',
#   'eskişehir',
#   'Diger',
#   'i̇stanbul',
#   'i̇zmir',
#   'i̇stanbul',
#   'Diger',
#   'adana',
#   'i̇stanbul',
#   'bartın',
#   'i̇stanbul',
#   'Diger',
#   'karaman',
#   'Diger',
#   'i̇zmir',
#   'tokat',
#   'van',
#   'samsun',
#   'bingöl',
#   'Diger',
#   'mersin',
#   'van',
#   'i̇zmir',
#   'Diger',
#   'i̇stanbul',
#   'giresun',
#   'ankara',
#   'çanakkale',
#   'ordu',
#   'çorum',
#   'Diger',
#   'i̇stanbul',
#   'kayseri',
#   'bursa',
#   'ankara',
#   'çankırı',
#   'manisa',
#   'manisa',
#   'manisa',
#   'sivas',
#   'ankara',
#   'kütahya',
#   'bursa',
#   'erzurum',
#   'i̇zmir',
#   'samsun',
#   'i̇zmir',
#   'i̇zmir',
#   'ankara',
#   'samsun',
#   'karabük',
#   'bursa',
#   'i̇stanbul',
#   'konya',
#   'bilecik',
#   'konya',
#   'i̇stanbul',
#   'i̇stanbul',
#   'Diger',
#   'i̇stanbul',
#   'siirt',
#   'i̇zmir',
#   'i̇zmir',
#   'ankara',
#   'ankara',
#   'kars',
#   'kütahya',
#   'ankara',
#   'Diger',
#   'Diger',
#   'ankara',
#   'i̇zmir',
#   'ankara',
#   'ankara',
#   'Diger',
#   'Diger',
#   'i̇stanbul',
#   'adıyaman',
#   'kırklareli',
#   'ankara',
#   'aydın',
#   'bursa',
#   'erzurum',
#   'antalya',
#   'manisa',
#   'elazığ',
#   'sivas',
#   'Diger',
#   'i̇zmir',
#   'çorum',
#   'i̇zmir',
#   'i̇stanbul',
#   'sakarya',
#   'antalya',
#   'ankara',
#   'ankara',
#   'Diger',
#   'muğla',
#   'i̇stanbul',
#   'zonguldak',
#   'kocaeli',
#   'adana',
#   'balıkesir',
#   'uşak',
#   'i̇zmir',
#   'sakarya',
#   'Diger',
#   'Diger',
#   'giresun',
#   'i̇stanbul',
#   'i̇zmir',
#   'i̇zmir',
#   'malatya',
#   'i̇zmir',
#   'i̇stanbul',
#   'konya',
#   'tekirdağ',
#   'i̇stanbul',
#   'tokat',
#   'zonguldak',
#   'muğla',
#   'ankara',
#   'çanakkale',
#   'afyonkarahisar',
#   'kayseri',
#   'bursa',
#   'eskişehir',
#   'tokat',
#   'i̇stanbul',
#   'i̇stanbul',
#   'ankara',
#   'şanlıurfa',
#   'Diger',
#   'ankara',
#   'Diger',
#   'mersin',
#   'diyarbakır',
#   'Diger',
#   'i̇stanbul',
#   'adana',
#   'i̇stanbul',
#   'ankara',
#   'ankara',
#   'kayseri',
#   'i̇stanbul',
#   'antalya',
#   'mersin',
#   'antalya',
#   'malatya',
#   'hatay',
#   'konya',
#   'ankara',
#   'Diger',
#   'i̇stanbul',
#   'i̇stanbul',
#   'edirne',
#   'i̇zmir',
#   'malatya',
#   'i̇stanbul',
#   'adana',
#   'ankara',
#   'i̇stanbul',
#   'manisa',
#   'i̇stanbul',
#   'i̇stanbul',
#   'Diger',
#   'Diger',
#   'şanlıurfa',
#   'Diger',
#   'Diger',
#   'ağrı',
#   'batman',
#   'i̇stanbul',
#   'Diger',
#   'aydın',
#   'karabük',
#   'ankara',
#   'trabzon',
#   'kocaeli',
#   'muğla',
#   'mersin',
#   'kocaeli',
#   'Diger',
#   'malatya',
#   'manisa',
#   'kayseri',
#   'i̇zmir',
#   'Diger',
#   'kırklareli',
#   'Diger',
#   'balıkesir',
#   'konya',
#   'i̇stanbul',
#   'i̇zmir',
#   'ankara',
#   'Diger',
#   'Diger',
#   'i̇zmir',
#   'i̇zmir',
#   'i̇stanbul',
#   'bursa',
#   'karabük',
#   'i̇stanbul',
#   'kocaeli',
#   'i̇stanbul',
#   'samsun',
#   'bursa',
#   'zonguldak',
#   'konya',
#   'muğla',
#   'kayseri',
#   'sivas',
#   'ankara',
#   'Diger',
#   'muğla',
#   'manisa',
#   'sakarya',
#   'Diger',
#   'eskişehir',
#   'adana',
#   'Diger',
#   'kahramanmaraş',
#   'i̇stanbul',
#   'i̇stanbul',
#   'ankara',
#   'ankara',
#   'nevşehir',
#   'kırıkkale',
#   'Diger',
#   'balıkesir',
#   'Diger',
#   'i̇stanbul',
#   'antalya',
#   'isparta',
#   'i̇stanbul',
#   'ankara',
#   'Diger',
#   'şanlıurfa',
#   'i̇stanbul',
#   'i̇stanbul',
#   'karaman',
#   'edirne',
#   'erzincan',
#   'ankara',
#   'kilis',
#   'sakarya',
#   'aydın',
#   'ankara',
#   'antalya',
#   'diyarbakır',
#   'Diger',
#   'mersin',
#   'i̇stanbul',
#   'sakarya',
#   'kırıkkale',
#   'Diger',
#   'i̇zmir',
#   'mersin',
#   'antalya',
#   'Diger',
#   'batman',
#   'kayseri',
#   'i̇stanbul',
#   'Diger',
#   'i̇stanbul',
#   'hatay',
#   'mersin',
#   'kayseri',
#   'i̇zmir',
#   'osmaniye',
#   'Diger',
#   'manisa',
#   'kayseri',
#   'tokat',
#   'diyarbakır',
#   'ankara',
#   'Diger',
#   'antalya',
#   'malatya',
#   'gaziantep',
#   'aydın',
#   'bursa',
#   'bursa',
#   'i̇stanbul',
#   'sivas',
#   'i̇stanbul',
#   'balıkesir',
#   'i̇zmir',
#   'denizli',
#   'konya',
#   'Diger',
#   'Diger',
#   'i̇zmir',
#   'sakarya',
#   'adana',
#   'i̇stanbul',
#   'denizli',
#   'i̇stanbul',
#   'Diger',
#   'çorum',
#   'mardin',
#   'kayseri',
#   'adana',
#   'Diger',
#   'konya',
#   'Diger',
#   'erzincan',
#   'bolu',
#   'kocaeli',
#   'ağrı',
#   'gaziantep',
#   'amasya',
#   'tokat',
#   'şanlıurfa',
#   'konya',
#   'malatya',
#   'osmaniye',
#   'i̇stanbul',
#   'i̇stanbul',
#   'adana',
#   'kayseri',
#   'i̇stanbul',
#   'adana',
#   'şanlıurfa',
#   'Diger',
#   'Diger',
#   'Diger',
#   'Diger',
#   'bursa',
#   'i̇stanbul',
#   'niğde',
#   'elazığ',
#   'malatya',
#   'eskişehir',
#   'ankara',
#   'ankara',
#   'rize',
#   'ankara',
#   'bursa',
#   'malatya',
#   'bursa',
#   'kocaeli',
#   'kırklareli',
#   'ankara',
#   'adana',
#   'mersin',
#   'kocaeli',
#   'Diger',
#   'mersin',
#   'aydın',
#   'kütahya',
#   'bursa',
#   'i̇stanbul',
#   'i̇stanbul',
#   'kayseri',
#   'nevşehir',
#   'kocaeli',
#   'amasya',
#   'manisa',
#   'i̇zmir',
#   'i̇stanbul',
#   'i̇zmir',
#   'kocaeli',
#   'Diger',
#   'i̇stanbul',
#   'adana',
#   'aydın',
#   'Diger',
#   'ankara',
#   'bursa',
#   'malatya',
#   'samsun',
#   'rize',
#   'i̇stanbul',
#   'i̇stanbul',
#   'i̇zmir',
#   'balıkesir',
#   'adana',
#   'mersin',
#   'diyarbakır',
#   'i̇stanbul',
#   'ankara',
#   'malatya',
#   'bursa',
#   'Diger',
#   'aksaray',
#   'i̇stanbul',
#   'Diger',
#   'Diger',
#   'i̇stanbul',
#   'batman',
#   'trabzon',
#   'muğla',
#   'şırnak',
#   'batman',
#   'kırıkkale',
#   'Diger',
#   'trabzon',
#   'niğde',
#   'aydın',
#   'i̇stanbul',
#   'kahramanmaraş',
#   'Diger',
#   'Diger',
#   'adana',
#   'samsun',
#   'aydın',
#   'Diger',
#   'i̇zmir',
#   'batman',
#   'i̇stanbul',
#   'bursa',
#   'antalya',
#   'kütahya',
#   'Diger',
#   'Diger',
#   'trabzon',
#   'denizli',
#   'bursa',
#   'ankara',
#   'ankara',
#   'balıkesir',
#   'antalya',
#   'i̇stanbul',
#   'i̇zmir',
#   'bursa',
#   'düzce',
#   'i̇stanbul',
#   'Diger',
#   'Diger',
#   'isparta',
#   'i̇stanbul',
#   'Diger',
#   'denizli',
#   'Diger',
#   'i̇zmir',
#   'zonguldak',
#   'sivas',
#   'Diger',
#   'balıkesir',
#   'kayseri',
#   'ordu',
#   'ankara',
#   'erzurum',
#   'mersin',
#   'i̇stanbul',
#   'Diger',
#   'kırklareli',
#   'i̇zmir',
#   'zonguldak',
#   'kocaeli',
#   'ankara',
#   'aydın',
#   'i̇stanbul',
#   'i̇zmir',
#   'i̇stanbul',
#   'balıkesir',
#   'i̇stanbul',
#   'i̇zmir',
#   'ankara',
#   'mersin',
#   'Diger',
#   'diyarbakır',
#   'yozgat',
#   'Diger',
#   'amasya',
#   'i̇zmir',
#   'isparta',
#   'antalya',
#   'isparta',
#   'kahramanmaraş',
#   'Diger',
#   'bolu',
#   'trabzon',
#   'i̇stanbul',
#   'i̇stanbul',
#   'kayseri',
#   'ağrı',
#   'i̇zmir',
#   'ankara',
#   'elazığ',
#   'manisa',
#   'i̇stanbul',
#   'sinop',
#   'zonguldak',
#   'aydın',
#   'muğla',
#   'i̇zmir',
#   'i̇stanbul',
#   'i̇stanbul',
#   'i̇stanbul',
#   'i̇stanbul',
#   'Diger',
#   'manisa',
#   'denizli',
#   'i̇stanbul',
#   'i̇stanbul',
#   'ankara',
#   'Diger',
#   'i̇stanbul',
#   'kocaeli',
#   'i̇zmir',
#   'van',
#   'mardin',
#   'şanlıurfa',
#   'i̇zmir',
#   'karabük',
#   'bursa',
#   'Diger',
#   'i̇zmir',
#   'i̇stanbul',
#   'i̇stanbul',
#   'çanakkale',
#   'i̇stanbul',
#   'batman',
#   'ankara',
#   'antalya',
#   'kocaeli',
#   'ankara',
#   'bolu',
#   'i̇stanbul',
#   'sivas',
#   'balıkesir',
#   'Diger',
#   'i̇stanbul',
#   'Diger',
#   'adana',
#   'ankara',
#   'karabük',
#   'i̇stanbul',
#   'manisa',
#   'aksaray',
#   'Diger',
#   'Diger',
#   'bursa',
#   'uşak',
#   'adana',
#   'i̇stanbul',
#   'i̇zmir',
#   'ankara',
#   'eskişehir',
#   'batman',
#   'kocaeli',
#   'Diger',
#   'balıkesir',
#   'aydın',
#   'aydın',
#   'trabzon',
#   'manisa',
#   'muğla',
#   'konya',
#   'giresun',
#   'i̇zmir',
#   'i̇stanbul',
#   'diyarbakır',
#   'hatay',
#   'mersin',
#   'i̇stanbul',
#   'ankara',
#   'gaziantep',
#   'yalova',
#   'i̇stanbul',
#   'i̇zmir',
#   'samsun',
#   'i̇stanbul',
#   'ankara',
#   'Diger',
#   'ankara',
#   'isparta',
#   'eskişehir',
#   'bursa',
#   'sivas',
#   'i̇stanbul',
#   'Diger',
#   'i̇zmir',
#   'mersin',
#   'samsun',
#   'çorum',
#   'i̇stanbul',
#   'i̇stanbul',
#   'ankara',
#   'i̇zmir',
#   'konya',
#   'adana',
#   'antalya',
#   'balıkesir',
#   'adana',
#   'antalya',
#   'gaziantep',
#   'bayburt',
#   'eskişehir',
#   'manisa',
#   'erzurum',
#   'i̇stanbul',
#   'bursa',
#   'ankara',
#   'aydın',
#   'van',
#   'diyarbakır',
#   'kayseri',
#   'ağrı',
#   'mersin',
#   'i̇stanbul',
#   'eskişehir',
#   'i̇stanbul',
#   'i̇zmir',
#   'i̇stanbul',
#   'adana',
#   'düzce',
#   'kocaeli',
#   'çanakkale',
#   'Diger',
#   'ankara',
#   'muş',
#   'gaziantep',
#   'balıkesir',
#   'rize',
#   'kırklareli',
#   'gaziantep',
#   'eskişehir',
#   'balıkesir',
#   'sakarya',
#   'mardin',
#   'i̇stanbul',
#   'erzurum',
#   'elazığ',
#   'Diger',
#   'antalya',
#   'adana',
#   'kayseri',
#   'i̇zmir',
#   'kocaeli',
#   'isparta',
#   'i̇zmir',
#   'i̇stanbul',
#   'antalya',
#   'çanakkale',
#   'erzincan',
#   'bolu',
#   'antalya',
#   'ankara',
#   'eskişehir',
#   'i̇stanbul',
#   'i̇zmir',
#   'ağrı',
#   'erzincan',
#   'ankara',
#   'i̇zmir',
#   'sivas',
#   'batman',
#   'diyarbakır',
#   'bursa',
#   'diyarbakır',
#   'adıyaman',
#   'i̇stanbul',
#   'van',
#   'kayseri',
#   'ankara',
#   'i̇zmir',
#   'i̇stanbul',
#   'i̇stanbul',
#   'adana',
#   'ankara',
#   'i̇stanbul',
#   'elazığ',
#   'Diger',
#   'i̇stanbul',
#   'i̇stanbul',
#   'i̇stanbul',
#   'antalya',
#   'bitlis',
#   'eskişehir',
#   'i̇stanbul',
#   'şanlıurfa',
#   'denizli',
#   'ankara',
#   'i̇zmir',
#   'i̇stanbul',
#   'i̇stanbul',
#   'i̇zmir',
#   'amasya',
#   'antalya',
#   'ankara',
#   'i̇stanbul',
#   'i̇stanbul',
#   'i̇stanbul',
#   'samsun',
#   'i̇stanbul',
#   'kocaeli',
#   'mersin',
#   'samsun',
#   'i̇stanbul',
#   'Diger',
#   'aksaray',
#   'aydın',
#   'bursa',
#   'bursa',
#   'antalya',
#   'balıkesir',
#   'uşak',
#   'adana',
#   'karabük',
#   'sakarya',
#   'i̇zmir',
#   'i̇stanbul',
#   'tunceli',
#   'malatya',
#   'bursa',
#   'i̇zmir',
#   'i̇stanbul',
#   'i̇stanbul',
#   'kayseri',
#   'i̇stanbul',
#   'gaziantep',
#   'Diger',
#   'i̇stanbul',
#   'antalya',
#   'i̇stanbul',
#   'aydın',
#   'ordu',
#   'ankara',
#   'ankara',
#   'ankara',
#   'bursa',
#   'i̇stanbul',
#   'çanakkale',
#   'i̇zmir',
#   'hatay',
#   'ankara',
#   'balıkesir',
#   'i̇zmir',
#   'i̇stanbul',
#   'i̇stanbul',
#   'ankara',
#   'gaziantep',
#   'Diger',
#   'manisa',
#   'elazığ',
#   'sinop',
#   'hatay',
#   'bursa',
#   'adana',
#   'zonguldak',
#   'i̇stanbul',
#   'kocaeli',
#   'elazığ',
#   'i̇stanbul',
#   'i̇stanbul',
#   'Diger',
#   'mardin',
#   'i̇stanbul',
#   'kayseri',
#   'balıkesir',
#   'i̇stanbul',
#   'i̇zmir',
#   'i̇stanbul',
#   'kocaeli',
#   'ankara',
#   'konya',
#   'erzurum',
#   'hatay',
#   'erzincan',
#   'kırşehir',
#   'i̇stanbul',
#   'adana',
#   'denizli',
#   'i̇stanbul',
#   'ankara',
#   'i̇stanbul',
#   'mersin',
#   'muğla',
#   'konya',
#   'i̇stanbul',
#   'i̇stanbul',
#   'Diger',
#   'i̇zmir',
#   'i̇zmir',
#   'edirne',
#   'i̇stanbul',
#   'i̇stanbul',
#   'i̇zmir',
#   'balıkesir',
#   'i̇zmir',
#   'antalya',
#   'Diger',
#   'i̇stanbul',
#   'kocaeli',
#   'şanlıurfa',
#   'kars',
#   'malatya',
#   'kırıkkale',
#   'mersin',
#   'Diger',
#   'bursa',
#   'manisa',
#   'i̇zmir',
#   'ankara',
#   'antalya',
#   'i̇stanbul',
#   'i̇zmir',
#   'bursa',
#   'mersin',
#   'kırklareli',
#   'aydın',
#   'Diger',
#   'i̇stanbul',
#   'ankara',
#   'diyarbakır',
#   'konya',
#   'ankara',
#   'kırşehir',
#   'gümüşhane',
#   'antalya',
#   'i̇stanbul',
#   'burdur',
#   'i̇zmir',
#   'düzce',
#   'şırnak',
#   'konya',
#   'bingöl',
#   'samsun',
#   'balıkesir',
#   'ankara',
#   'sakarya',
#   'gümüşhane',
#   'eskişehir',
#   'kilis',
#   'i̇stanbul',
#   'antalya',
#   'i̇zmir',
#   'i̇stanbul',
#   'Diger',
#   'i̇stanbul',
#   'erzincan',
#   'i̇stanbul',
#   'siirt',
#   'i̇zmir',
#   'i̇stanbul',
#   'samsun',
#   'i̇zmir',
#   'i̇stanbul',
#   'sivas',
#   'manisa',
#   'antalya',
#   'denizli',
#   'i̇stanbul',
#   'i̇stanbul',
#   'kayseri',
#   'yozgat',
#   'i̇stanbul',
#   'malatya',
#   'zonguldak',
#   'ankara',
#   'antalya',
#   'i̇stanbul',
#   'bursa',
#   'mersin',
#   'i̇stanbul',
#   'antalya',
#   'i̇zmir',
#   'kayseri',
#   'gaziantep',
#   'i̇stanbul',
#   'i̇zmir',
#   'ankara',
#   'ankara',
#   'ankara',
#   'i̇stanbul',
#   'diyarbakır',
#   'diyarbakır',
#   'antalya',
#   'i̇stanbul',
#   'ankara',
#   'i̇zmir',
#   'kilis',
#   'i̇zmir',
#   'i̇stanbul',
#   'sakarya',
#   'niğde',
#   'denizli',
#   'antalya',
#   'i̇zmir',
#   'düzce',
#   'antalya',
#   'i̇stanbul',
#   'kayseri',
#   'trabzon',
#   'ordu',
#   'adıyaman',
#   'erzurum',
#   'aydın',
#   'bursa',
#   'nevşehir',
#   'konya',
#   'aydın',
#   'i̇zmir',
#   'i̇stanbul',
#   'eskişehir',
#   'ankara',
#   'tokat',
#   'samsun',
#   'kayseri',
#   'kırıkkale',
#   'bursa',
#   'i̇stanbul',
#   'malatya',
#   'antalya',
#   'i̇stanbul',
#   'i̇zmir',
#   'antalya',
#   'adıyaman',
#   'aydın',
#   'i̇zmir',
#   'erzurum',
#   'i̇stanbul',
#   'i̇zmir',
#   'mersin',
#   'sivas',
#   'muş',
#   'çanakkale',
#   'i̇stanbul',
#   'eskişehir',
#   'tekirdağ',
#   'i̇stanbul',
#   'adana',
#   'kocaeli',
#   'erzurum',
#   'i̇zmir',
#   'giresun',
#   'kayseri',
#   'balıkesir',
#   'sivas',
#   'niğde',
#   'ankara',
#   ...])

# %%
train["Dogum Yeri"]=dogum_yeri
train["Dogum Yeri"]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 train["Dogum Yeri"]=dogum_yeri
#       2 train["Dogum Yeri"]
#
# File ~\Desktop\Datathon24\env\Lib\site-packages\pandas\core\frame.py:4311, in DataFrame.__setitem__(self, key, value)
#    4308     self._setitem_array([key], value)
#    4309 else:
#    4310     # set column
# -> 4311     self._set_item(key, value)
#
# File ~\Desktop\Datathon24\env\Lib\site-packages\pandas\core\frame.py:4524, in DataFrame._set_item(self, key, value)
#    4514 def _set_item(self, key, value) -> None:
#    4515     """
#    4516     Add series to DataFrame in specified column.
#    4517
#    (...)
#    4522     ensure homogeneity.
#    4523     """
# -> 4524     value, refs = self._sanitize_column(value)
#    4526     if (
#    4527         key in self.columns
#    4528         and value.ndim == 1
#    4529         and not isinstance(value.dtype, ExtensionDtype)
#    4530     ):
#    4531         # broadcast across multiple columns if necessary
#    4532         if not self.columns.is_unique or isinstance(self.columns, MultiIndex):
#
# File ~\Desktop\Datathon24\env\Lib\site-packages\pandas\core\frame.py:5266, in DataFrame._sanitize_column(self, value)
#    5263     return _reindex_for_setitem(value, self.index)
#    5265 if is_list_like(value):
# -> 5266     com.require_length_match(value, self.index)
#    5267 arr = sanitize_array(value, self.index, copy=True, allow_2d=True)
#    5268 if (
#    5269     isinstance(value, Index)
#    5270     and value.dtype == "object"
#    (...)
#    5273     # TODO: Remove kludge in sanitize_array for string mode when enforcing
#    5274     # this deprecation
#
# File ~\Desktop\Datathon24\env\Lib\site-packages\pandas\core\common.py:573, in require_length_match(data, index)
#     569 """
#     570 Check the length of data matches the length of the index.
#     571 """
#     572 if len(data) != len(index):
# --> 573     raise ValueError(
#     574         "Length of values "
#     575         f"({len(data)}) "
#     576         "does not match length of index "
#     577         f"({len(index)})"
#     578     )
#
# ValueError: Length of values (65123) does not match length of index (65125)

# %%
dogum_yeri=[]
for k in dogum_y[:1]:
    result = re.split(r'[ ,/-]', k)
    print(result)
    for i in result:
        print(i)
        il,ilce in city_district_dict.items():
        print(il)
        print(ilce)
            if i == il:
                dogum_yeri.append(il)
            elif i in ilce:
                dogum_yeri.append(il)
            dogum_yeri.append("Diger")
